# %%
import tensorflow as tf
import numpy as np
import scipy.io as sio
import scipy as sp
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\hater\Anaconda3new\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\hater\Anaconda3new\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\hater\Anaconda3new\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hater\\Documents\\BA\\#\\3dcnn4fmri-master\\Python_code'

# %%
from scipy import stats

# %%
tp2 = np.load('C:\\Users\\hater\\Documents\\BA\\#\\saliency_maps\\scrambled_OSD_10_mean_tp.npy')

# %%
tp2_max=np.amax(tp2, axis=2)
plt.imshow(tp2_max) # matplotlib default color map
plt.colorbar()

# %%
#save as an nii image

# %%
import nibabel as nib

# %%
img = nib.load(r'C:\Users\hater\Documents\BA\#\wmprage.nii') # to get appropriate header
new_image = nib.Nifti1Image(tp2, None)
header_info = img.header
#header_info['pixdim'][1:4]  = [2,2,2]
new_image = nib.Nifti1Image(tp2,None,  img.header)

# %%
nib.save(new_image, r'C:\Users\hater\Documents\BA\#\saliency_maps\scrambled_OSD_10_mean_tp.nii')
